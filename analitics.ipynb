# %%
import json
from collections import defaultdict
import pandas as pd
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import utils
import plot_utils

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
ger = pd.read_csv("analitics/traditional_Germany.csv")
ita = pd.read_csv("analitics/traditional_Italy.csv")
eng = pd.read_csv("analitics/traditional_England.csv")
fra = pd.read_csv("analitics/traditional_France.csv")

# %%
#proporção da target

pct = pd.DataFrame(eng['winner'].value_counts())
pct['Percentage'] = 100*pct['winner']/eng.shape[0]
pct
# Out:
#    winner  Percentage
# 0     209        55.0
# 1     171        45.0

# %%
pd.plotting.scatter_matrix(ger, figsize=(18,18))
plt.show()

# #Using Pearson Correlation
# plt.figure(figsize=(10,8))
# cor = ger.iloc[:,:].corr()
# sns.heatmap(cor, annot=False, cmap=plt.cm.CMRmap_r)
# plt.show()

# %%
#Using Pearson Correlation
plt.figure(figsize=(10,8))
cor = ita.iloc[:,:].corr()
sns.heatmap(cor, annot=False, cmap=plt.cm.CMRmap_r)
plt.show()

# %%
#Using Pearson Correlation
plt.figure(figsize=(10,8))
cor = eng.iloc[:,:].corr()
sns.heatmap(cor, annot=False, cmap=plt.cm.CMRmap_r)
plt.show()

# %%
#Using Pearson Correlation
plt.figure(figsize=(10,8))
cor = fra.iloc[:,:].corr()
sns.heatmap(cor, annot=False, cmap=plt.cm.CMRmap_r)
plt.show()
