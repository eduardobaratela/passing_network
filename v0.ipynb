# %%
import pandas as pd
import networkx as nx

# %%
df = pd.read_json('events\events_World_Cup.json')

# %%
df
# Out:
#         eventId             subEventName  \
# 0             8              Simple pass
# 1             8                High pass
# 2             1                 Air duel
# 3             1                 Air duel
# 4             8              Simple pass
# ...         ...                      ...
# 101754        8              Simple pass
# 101755        7                    Touch
# 101756        8                    Cross
# 101757        4  Goalkeeper leaving line
# 101758        8                   Launch
#
#                                             tags  playerId  \
# 0                                 [{'id': 1801}]    122671
# 1                                 [{'id': 1801}]    139393
# 2                    [{'id': 703}, {'id': 1801}]    103668
# 3                    [{'id': 701}, {'id': 1802}]    122940
# 4                                 [{'id': 1801}]    122847
# ...                                          ...       ...
# 101754                            [{'id': 1801}]      3476
# 101755                                        []     14812
# 101756  [{'id': 401}, {'id': 801}, {'id': 1802}]     14812
# 101757                                        []     25381
# 101758                            [{'id': 1802}]     25381
#
#                                         positions  matchId  \
# 0        [{'y': 50, 'x': 50}, {'y': 53, 'x': 35}]  2057954
# 1        [{'y': 53, 'x': 35}, {'y': 19, 'x': 75}]  2057954
# 2        [{'y': 81, 'x': 25}, {'y': 83, 'x': 37}]  2057954
# 3        [{'y': 19, 'x': 75}, {'y': 17, 'x': 63}]  2057954
# 4        [{'y': 17, 'x': 63}, {'y': 15, 'x': 71}]  2057954
# ...                                           ...      ...
# 101754    [{'y': 20, 'x': 46}, {'y': 6, 'x': 64}]  2058017
# 101755     [{'y': 6, 'x': 64}, {'y': 2, 'x': 82}]  2058017
# 101756  [{'y': 2, 'x': 82}, {'y': 100, 'x': 100}]  2058017
# 101757     [{'y': 0, 'x': 0}, {'y': 98, 'x': 18}]  2058017
# 101758     [{'y': 43, 'x': 14}, {'y': 0, 'x': 0}]  2058017
#
#                       eventName  teamId matchPeriod     eventSec subEventId  \
# 0                          Pass   16521          1H     1.656214         85
# 1                          Pass   16521          1H     4.487814         83
# 2                          Duel   14358          1H     5.937411         10
# 3                          Duel   16521          1H     6.406961         10
# 4                          Pass   16521          1H     8.562167         85
# ...                         ...     ...         ...          ...        ...
# 101754                     Pass    9598          2H  2978.301867         85
# 101755       Others on the ball    9598          2H  2979.084611         72
# 101756                     Pass    9598          2H  2983.448628         80
# 101757  Goalkeeper leaving line    4418          2H  2985.869275         40
# 101758                     Pass    4418          2H  3002.148765         84
#
#                id
# 0       258612104
# 1       258612106
# 2       258612077
# 3       258612112
# 4       258612110
# ...           ...
# 101754  263885652
# 101755  263885653
# 101756  263885654
# 101757  263885613
# 101758  263885618
#
# [101759 rows x 12 columns]

# %%
match = df[df['matchId'] == 2057954]
passe = match[match['eventId'] == 8]

# %%
passe
# Out:
#       eventId subEventName            tags  playerId  \
# 0           8  Simple pass  [{'id': 1801}]    122671
# 1           8    High pass  [{'id': 1801}]    139393
# 4           8  Simple pass  [{'id': 1801}]    122847
# 5           8  Simple pass  [{'id': 1801}]    122832
# 7           8  Simple pass  [{'id': 1801}]    122847
# ...       ...          ...             ...       ...
# 1578        8  Simple pass  [{'id': 1801}]    102157
# 1579        8  Simple pass  [{'id': 1802}]      4513
# 1581        8  Simple pass  [{'id': 1801}]    220971
# 1582        8  Simple pass  [{'id': 1801}]    103682
# 1588        8  Simple pass  [{'id': 1802}]    122623
#
#                                        positions  matchId eventName  teamId  \
# 0       [{'y': 50, 'x': 50}, {'y': 53, 'x': 35}]  2057954      Pass   16521
# 1       [{'y': 53, 'x': 35}, {'y': 19, 'x': 75}]  2057954      Pass   16521
# 4       [{'y': 17, 'x': 63}, {'y': 15, 'x': 71}]  2057954      Pass   16521
# 5       [{'y': 15, 'x': 71}, {'y': 11, 'x': 92}]  2057954      Pass   16521
# 7       [{'y': 11, 'x': 88}, {'y': 13, 'x': 88}]  2057954      Pass   16521
# ...                                          ...      ...       ...     ...
# 1578    [{'y': 44, 'x': 56}, {'y': 33, 'x': 66}]  2057954      Pass   14358
# 1579    [{'y': 33, 'x': 66}, {'y': 38, 'x': 53}]  2057954      Pass   14358
# 1581    [{'y': 64, 'x': 69}, {'y': 72, 'x': 73}]  2057954      Pass   14358
# 1582    [{'y': 72, 'x': 73}, {'y': 70, 'x': 78}]  2057954      Pass   14358
# 1588  [{'y': 50, 'x': 50}, {'y': 100, 'x': 100}]  2057954      Pass   16521
#
#      matchPeriod     eventSec subEventId         id
# 0             1H     1.656214         85  258612104
# 1             1H     4.487814         83  258612106
# 4             1H     8.562167         85  258612110
# 5             1H    10.991292         85  258612113
# 7             1H    15.039163         85  258612116
# ...          ...          ...        ...        ...
# 1578          2H  2861.719049         85  258613766
# 1579          2H  2863.131899         85  258613767
# 1581          2H  2865.964868         85  258613768
# 1582          2H  2868.496551         85  258613771
# 1588          2H  2983.382036         85  258614079
#
# [827 rows x 12 columns]

# %%
passe['y'] = passe['positions'].apply(lambda x : x[0]['y'])
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17072/1557725725.py in <module>
# ----> 1 passe['y'] = passe['positions'].apply(lambda x : passe['positions'].loc[x, 0]['y'])
#
# c:\Users\eduar\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# c:\Users\eduar\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# c:\Users\eduar\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1096                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1097                 # "Callable[[Any], Any]"
# -> 1098                 mapped = lib.map_infer(
#    1099                     values,
#    1100                     f,  # type: ignore[arg-type]
#
# c:\Users\eduar\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\AppData\Local\Temp/ipykernel_17072/1557725725.py in <lambda>(x)
# ----> 1 passe['y'] = passe['positions'].apply(lambda x : passe['positions'].loc[x, 0]['y'])
#
# c:\Users\eduar\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# c:\Users\eduar\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1101
#    1102         # no multi-index, so validate all of the indexers
# -> 1103         self._has_valid_tuple(tup)
#    1104
#    1105         # ugly hack for GH #836
#
# c:\Users\eduar\anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_tuple(self, key)
#     749         Check the key for valid keys across my indexer.
#     750         """
# --> 751         self._validate_key_length(key)
#     752         for i, k in enumerate(key):
#     753             try:
#
# c:\Users\eduar\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key_length(self, key)
#     790     def _validate_key_length(self, key: Sequence[Any]) -> None:
#     791         if len(key) > self.ndim:
# --> 792             raise IndexingError("Too many indexers")
#     793
#     794     def _getitem_tuple_same_dim(self, tup: tuple):
#
# IndexingError: Too many indexers

# %%
y  = passe['positions'].apply(pd.Series)

# %%
passe['origem'] = y[0]
passe['destino'] = y[1]
# Out:
# C:\Users\eduar\AppData\Local\Temp/ipykernel_17072/2817985966.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   passe['origem'] = y[0]
# C:\Users\eduar\AppData\Local\Temp/ipykernel_17072/2817985966.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   passe['destino'] = y[1]

# %%
z = lambda x :passe['origem'][x]['y']

# %%
aux = passe['origem'].apply(pd.Series)

# %%
passe['origem_y'] = aux['y']
passe['origem_x'] = aux['x']
# Out:
# C:\Users\eduar\AppData\Local\Temp/ipykernel_17072/2968213896.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   passe['origem_y'] = aux['y']
# C:\Users\eduar\AppData\Local\Temp/ipykernel_17072/2968213896.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   passe['origem_x'] = aux['x']

# %%
passe[['playerId','origem_y', 'origem_x']].groupby(by=['playerId']).mean()
# Out:
#            origem_y   origem_x
# playerId
# 4513      22.409091  65.090909
# 41123     82.192308  57.730769
# 101576    58.117647  18.058824
# 101583    31.807692  32.423077
# 101590    52.500000  59.625000
# 101669    46.000000  69.285714
# 101699    72.823529  61.529412
# 101707    56.105263  65.000000
# 101857    13.451613  49.548387
# 102157    50.103448  48.586207
# 103668    71.151515  32.575758
# 103682    58.964286  61.250000
# 122561    55.416667  13.541667
# 122577    62.970588  48.176471
# 122615    87.750000  72.500000
# 122623    49.000000  50.500000
# 122651    30.600000  31.927273
# 122671    58.000000  46.200000
# 122749    49.000000  51.000000
# 122832    25.159091  54.454545
# 122839    70.724138  32.879310
# 122847    40.792208  51.129870
# 122888    78.457143  56.514286
# 122940    13.666667  46.298246
# 139393    47.981132  44.792453
# 220971    61.400000  55.400000
# 257800    38.657895  65.973684
# 292954    89.134328  53.880597

# %%
passe[['playerId','origem_y']]
# Out:
#       playerId  origem_y
# 0       122671        50
# 1       139393        53
# 4       122847        17
# 5       122832        15
# 7       122847        11
# ...        ...       ...
# 1578    102157        44
# 1579      4513        33
# 1581    220971        64
# 1582    103682        72
# 1588    122623        50
#
# [827 rows x 2 columns]
